# %%
#import the libraries
import math
import pandas_datareader as web
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
#get the stock data
df = web.DataReader('AAPL', data_source='yahoo' , start='2012-01-01' , end='2022-02-24')

#show the data
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2012-01-03   14.732143   14.607143   14.621429   14.686786  302220800.0
# 2012-01-04   14.810000   14.617143   14.642857   14.765714  260022000.0
# 2012-01-05   14.948214   14.738214   14.819643   14.929643  271269600.0
# 2012-01-06   15.098214   14.972143   14.991786   15.085714  318292800.0
# 2012-01-09   15.276786   15.048214   15.196429   15.061786  394024400.0
# ...                ...         ...         ...         ...          ...
# 2022-02-17  171.910004  168.470001  171.029999  168.880005   69589300.0
# 2022-02-18  170.539993  166.190002  169.820007  167.300003   82772700.0
# 2022-02-22  166.690002  162.149994  164.979996  164.320007   91162800.0
# 2022-02-23  166.149994  159.750000  165.539993  160.070007   90009200.0
# 2022-02-24  162.850006  152.000000  152.580002  162.740005  141147500.0
#
#              Adj Close
# Date
# 2012-01-03   12.575914
# 2012-01-04   12.643498
# 2012-01-05   12.783865
# 2012-01-06   12.917510
# 2012-01-09   12.897019
# ...                ...
# 2022-02-17  168.880005
# 2022-02-18  167.300003
# 2022-02-22  164.320007
# 2022-02-23  160.070007
# 2022-02-24  162.740005
#
# [2554 rows x 6 columns]

# %%
#get the number of rows and column in the data set
df.shape
# Out:
# (2554, 6)

# %%
#Visualing the closing price history
plt.figure(figsize=(16,8))
plt.title('Close Price History')
plt.plot(df['Close'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Closing Price USD($)', fontsize=18)
plt.show()

# %%
#Create a new data
data = df.filter(['Close'])
#convert the dataframe to a numpy array
dataset = data.values
#get the number of rows to train the model on
training_data_len = math.ceil(len(dataset)*.8)
training_data_len
# Out:
# 2044

# %%
#Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(dataset)

scaled_data
# Out:
# array([[0.00439887],
#        [0.00486851],
#        [0.00584391],
#        ...,
#        [0.89474161],
#        [0.8694534 ],
#        [0.88534034]])

# %%
#creating the training data set
#create the scaled training data set
train_data = scaled_data[0:training_data_len,:]
#split the data into x_train and y_train data sets
x_train = []
y_train = []
for i in range(60, len(train_data)):
    x_train.append(train_data[i-60:i,0])
    y_train.append(train_data[i,0])
    if i<=61:
        print(x_train)
        print(y_train)
        print()
# Out:
# [array([0.00439887, 0.00486851, 0.00584391, 0.00677256, 0.00663019,
#        0.00695107, 0.00680444, 0.00655793, 0.00622217, 0.00726133,
#        0.00819848, 0.00790947, 0.0063263 , 0.00783722, 0.00634968,
#        0.01192796, 0.01149658, 0.01205972, 0.01327737, 0.01401476,
#        0.01395314, 0.01372576, 0.01469479, 0.01560643, 0.01663922,
#        0.01830739, 0.02181161, 0.02186474, 0.02381555, 0.02527333,
#        0.0227679 , 0.02373267, 0.02371354, 0.02641875, 0.02603411,
#        0.026746  , 0.02802528, 0.02873719, 0.03078787, 0.03228178,
#        0.03271317, 0.03286405, 0.03030973, 0.02969346, 0.02978484,
#        0.03218616, 0.03286193, 0.03431335, 0.03773469, 0.04229932,
#        0.04144504, 0.04144716, 0.04474738, 0.04578017, 0.04504489,
#        0.04437338, 0.04367423, 0.04599691, 0.04759072, 0.04825798])]
# [0.04660893460974819]
#
# [array([0.00439887, 0.00486851, 0.00584391, 0.00677256, 0.00663019,
#        0.00695107, 0.00680444, 0.00655793, 0.00622217, 0.00726133,
#        0.00819848, 0.00790947, 0.0063263 , 0.00783722, 0.00634968,
#        0.01192796, 0.01149658, 0.01205972, 0.01327737, 0.01401476,
#        0.01395314, 0.01372576, 0.01469479, 0.01560643, 0.01663922,
#        0.01830739, 0.02181161, 0.02186474, 0.02381555, 0.02527333,
#        0.0227679 , 0.02373267, 0.02371354, 0.02641875, 0.02603411,
#        0.026746  , 0.02802528, 0.02873719, 0.03078787, 0.03228178,
#        0.03271317, 0.03286405, 0.03030973, 0.02969346, 0.02978484,
#        0.03218616, 0.03286193, 0.03431335, 0.03773469, 0.04229932,
#        0.04144504, 0.04144716, 0.04474738, 0.04578017, 0.04504489,
#        0.04437338, 0.04367423, 0.04599691, 0.04759072, 0.04825798]), array([0.00486851, 0.00584391, 0.00677256, 0.00663019, 0.00695107,
#        0.00680444, 0.00655793, 0.00622217, 0.00726133, 0.00819848,
#        0.00790947, 0.0063263 , 0.00783722, 0.00634968, 0.01192796,
#        0.01149658, 0.01205972, 0.01327737, 0.01401476, 0.01395314,
#        0.01372576, 0.01469479, 0.01560643, 0.01663922, 0.01830739,
#        0.02181161, 0.02186474, 0.02381555, 0.02527333, 0.0227679 ,
#        0.02373267, 0.02371354, 0.02641875, 0.02603411, 0.026746  ,
#        0.02802528, 0.02873719, 0.03078787, 0.03228178, 0.03271317,
#        0.03286405, 0.03030973, 0.02969346, 0.02978484, 0.03218616,
#        0.03286193, 0.03431335, 0.03773469, 0.04229932, 0.04144504,
#        0.04144716, 0.04474738, 0.04578017, 0.04504489, 0.04437338,
#        0.04367423, 0.04599691, 0.04759072, 0.04825798, 0.04660893])]
# [0.04660893460974819, 0.04441800167645807]

# %%
#Convert the X_train and Y_train to numpy arrays
x_train , y_train = np.array(x_train), np.array(y_train)

# %%
#Reshape the data
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
x_train.shape
# Out:
# (1984, 60, 1)

# %%
#Building the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape =(x_train.shape[1],1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# %%
#compile the Model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
#train the model
model.fit(x_train, y_train, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 62/62 [==============================] - 11s 97ms/step - loss: 0.0022
# Epoch 2/100
# 62/62 [==============================] - 4s 66ms/step - loss: 1.4033e-04
# Epoch 3/100
# 62/62 [==============================] - 4s 69ms/step - loss: 1.3355e-04
# Epoch 4/100
# 62/62 [==============================] - 7s 119ms/step - loss: 1.4213e-04
# Epoch 5/100
# 62/62 [==============================] - 8s 121ms/step - loss: 1.0401e-04
# Epoch 6/100
# 62/62 [==============================] - 7s 121ms/step - loss: 9.8232e-05
# Epoch 7/100
# 62/62 [==============================] - 7s 111ms/step - loss: 9.0819e-05
# Epoch 8/100
# 62/62 [==============================] - 4s 63ms/step - loss: 9.2385e-05
# Epoch 9/100
# 62/62 [==============================] - 6s 91ms/step - loss: 7.9832e-05
# Epoch 10/100
# 62/62 [==============================] - 8s 123ms/step - loss: 7.4341e-05
# Epoch 11/100
# 62/62 [==============================] - 8s 123ms/step - loss: 8.0402e-05
# Epoch 12/100
# 62/62 [==============================] - 8s 121ms/step - loss: 7
# 62/62 [==============================] - 8s 122ms/step - loss: 2.0038e-05
# Epoch 84/100
# 62/62 [==============================] - 8s 123ms/step - loss: 2.0765e-05
# Epoch 85/100
# 62/62 [==============================] - 6s 102ms/step - loss: 1.8305e-05
# Epoch 86/100
# 62/62 [==============================] - 4s 61ms/step - loss: 2.0277e-05
# Epoch 87/100
# 62/62 [==============================] - 8s 124ms/step - loss: 1.6633e-05
# Epoch 88/100
# 62/62 [==============================] - 8s 122ms/step - loss: 1.9498e-05
# Epoch 89/100
# 62/62 [==============================] - 8s 123ms/step - loss: 1.4325e-05
# Epoch 90/100
# 62/62 [==============================] - 8s 122ms/step - loss: 1.5911e-05
# Epoch 91/100
# 62/62 [==============================] - 8s 125ms/step - loss: 1.4076e-05
# Epoch 92/100
# 62/62 [==============================] - 8s 129ms/step - loss: 1.7351e-05
# Epoch 93/100
# 62/62 [==============================] - 5s 81ms/step - loss: 1.9433e-05
# Epoch 94/100
# 62/62 [==============================] - 5s 84ms/step - loss: 1.5197e-05
# Epoch 95/100
# 62/62 [==============================] - 8s 124ms/step - loss: 1.4607e-05
# Epoch 96/100
# 62/62 [==============================] - 8s 122ms/step - loss: 1.9098e-05
# Epoch 97/100
# 62/62 [==============================] - 8s 122ms/step - loss: 1.6183e-05
# Epoch 98/100
# 62/62 [==============================] - 7s 109ms/step - loss: 1.3661e-05
# Epoch 99/100
# 62/62 [==============================] - 4s 62ms/step - loss: 1.8044e-05
# Epoch 100/100
# 62/62 [==============================] - 7s 117ms/step - loss: 1.4606e-05

# %%
#create the testing data set
#create a new array containing scaled values from index 1543 to 2003
test_data = scaled_data[training_data_len - 60: , :]
#create the data sets x_test adn y_test
x_test = []
y_test = dataset[training_data_len:,:]
for i in range(60, len(test_data)):
    x_test.append(test_data[i-60:i,0])

# %%
#convert the data to a numpy array
x_test = np.array(x_test)

# %%
#resahpe the data
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

# %%
#get the models predicted price values
predictions = model.predict(x_test)
predictions = scaler.inverse_transform(predictions)

# %%
#get the root mean squared error (RMSE)
rmse =  np.sqrt(np.mean(predictions - y_test)**2)
print(rmse)
error = []
x = np.linspace(0, 520, 600)
y = np.linspace(0, 0, 600)
error.append(predictions - y_test)
nperr = np.array(predictions - y_test)
scaled_error = scaler.fit_transform(nperr)
plt.figure(figsize=(25,10))
plt.plot(nperr, linewidth=3)
plt.plot(x,y)
#plt.plot(scaled_error, linewidth=3)
plt.title("Scaled 1D Error")
plt.show()
# Out:
# 3.501925427305932

# %%
#plot the date
train = data[:training_data_len]
valid = data[training_data_len:]
valid['Predictions'] = predictions
valid['Error'] = nperr
#visualize the data
plt.figure(figsize=(16,8))
plt.title('Model')
plt.xlabel('Date')
plt.ylabel('Close Price USD ($)')
plt.plot(train['Close'])
plt.plot(valid[['Close', 'Predictions']])
plt.legend(['Train', 'Val', 'Predictions'], loc='lower right')
plt.show()
# Out:
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\Abhishek Rao\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.7_qbz5n2kfra8p0\LocalCache\local-packages\Python37\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %%
#show the valid and predicted prices
valid
# Out:
#                  Close  Predictions     Error
# Date
# 2020-02-19   80.904999    78.258156 -2.646843
# 2020-02-20   80.074997    79.832664 -0.242332
# 2020-02-21   78.262497    78.654915  0.392418
# 2020-02-24   74.544998    76.753632  2.208633
# 2020-02-25   72.019997    73.115623  1.095627
# ...                ...          ...       ...
# 2022-02-17  168.880005   164.441467 -4.438538
# 2022-02-18  167.300003   161.605484 -5.694519
# 2022-02-22  164.320007   162.196564 -2.123444
# 2022-02-23  160.070007   157.982025 -2.087982
# 2022-02-24  162.740005   154.345062 -8.394943
#
# [510 rows x 3 columns]

# %%
#get the Quote
apple_quote = web.DataReader('AAPL', data_source = 'yahoo', start='2012-01-01', end='2022-02-24')
#create new data frame
new_df = apple_quote.filter(['Close'])
#get the last 60 days closing price values and convert the dataframe to an array
last_60_days = new_df[-60:].values
#scale the data to be values between 0 and 1
last_60_days_scaled = scaler.transform(last_60_days)
#create the empty list
x_test = []
#append the past 60 days
x_test.append(last_60_days_scaled)
#convert the x_test data set to a numpy array
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))
#get the predicted scaled price
pred_price = model.predict(x_test)
#undo the scaling
pred_price = scaler.inverse_transform(pred_price)
print(pred_price)
# Out:
# [[48.475666]]

# %%
#The Error Model 
#get the number of rows and column in the data set
valid.shape
# Out:
# (510, 3)

# %%
#Visualing the closing price Error history
plt.figure(figsize=(16,8))
plt.title('Close Price Error History')
plt.plot(valid['Error'])
plt.xlabel('Date', fontsize=18)
plt.ylabel('Closing Price Error USD($)', fontsize=18)
plt.show()

# %%
#Create a new Error data
errdata = valid.filter(['Close'])
#convert the Error dataframe to a numpy array
errdataset = errdata.values
#get the number of rows to train the model on
training_errdata_len = math.ceil(len(errdataset)*.8)
training_errdata_len
# Out:
# 408

# %%
#Scale the data
scaler = MinMaxScaler(feature_range=(0,1))
scaled_errdata = scaler.fit_transform(errdataset)

scaled_errdata
# Out:
# array([[0.19705363],
#        [0.190462  ],
#        [0.17606765],
#        [0.14654436],
#        [0.12649154],
#        [0.13556496],
#        [0.09758373],
#        [0.09726605],
#        [0.14779519],
#        [0.12895351],
#        [0.15559791],
#        [0.13610106],
#        [0.12837772],
#        [0.08299089],
#        [0.12105149],
#        [0.1013759 ],
#        [0.04737229],
#        [0.1064189 ],
#        [0.03542004],
#        [0.05656483],
#        [0.04427503],
#        [0.04052257],
#        [0.00966905],
#        [0.        ],
#        [0.04469198],
#        [0.0419918 ],
#        [0.06764351],
#        [0.04639945],
#        [0.0604364 ],
#        [0.05940397],
#        [0.03283898],
#        [0.04082037],
#        [0.03383169],
#        [0.07564478],
#        [0.06960907],
#        [0.08279233],
#        [0.08660432],
#        [0.09704768],
#        [0.12444655],
#        [0.11924474],
#        [0.12373183],
#        [0.11600849],
#        [0.10435404],
#        [0.08735879],
#        [0.10270616],
#        [0.10058174],
#        [0.11634604],
#        [0.11674315],
#        [0.10762998],
#        [0.12579669],
#        [0.13784818],
#        [0.12845715],
#        [0.13657754],
#        [0.14531341],
#        [0.15140868],
#        [0.15758333],
#        [0.17027024],
#        [0.17995914],
#        [0.17281159],
#        [0.16534636],
#        [0.16909885],
#        [0.16546548],
#        [0.17985983],
#        [0.1762464 ],
#        [0.18833764],
#        [0.18361231],
#        [0.1876626 ],
#        [0.18337407],
#        [0.18611391],
#        [0.1863919 ],
#        [0.18577642],
#        [0.19353945],
#        [0.19649772],
#        [0.20003177],
#        [0.1944726 ],
#        [0.21269881],
#        [0.21659023],
#        [0.23749677],
#        [0.25506781],
#        [0.22143467],
#        [0.2271924 ],
#        [0.23551135],
#        [0.25355887],
#        [0.25258603],
#        [0.25286402],
#        [0.24887329],
#        [0.26703994],
#        [0.74276808],
#        [0.73276157],
#        [0.72624931],
#        [0.73466762],
#        [0.77056406],
#        [0.76031931],
#        [0.76571961],
#        [0.77477315],
#        [0.77993534],
#        [0.79891601],
#        [0.7863681 ],
#        [0.77810878],
#        [0.73760602],
#        [0.74221222],
#        [0.73085552],
#        [0.7380825 ],
#        [0.73617645],
#        [0.71449562],
#        [0.68971753],
#        [0.69360889],
#        [0.71282793],
#        [0.72061077],
#        [0.72132549],
#        [0.70901582],
#        [0.68153758],
#        [0.68884393],
#        [0.67828145],
#        [0.68741436],
#        [0.65953901],
#        [0.67518419],
#        [0.6822523 ],
#        [0.69249705],
#        [0.68939979],
#        [0.68868507],
#        [0.67836082],
#        [0.67359587],
#        [0.69622966],
#        [0.70480672],
#        [0.7183871 ],
#        [0.7359382 ],
#        [0.73990906],
#        [0.74165624],
#        [0.73538235],
#        [0.73498524],
#        [0.74038566],
#        [0.73665305],
#        [0.76619621],
#        [0.74419765],
#        [0.73752664],
#        [0.74594483],
#        [0.75761916],
#        [0.75341006],
#        [0.75595134],
#        [0.74928034],
#        [0.75221873],
#        [0.7292672 ],
#        [0.72887009],
#        [0.74570659],
#        [0.74578597],
#        [0.75372767],
#        [0.77350257],
#        [0.80828717],
#        [0.82957101],
#        [0.83330362],
#        [0.83640089],
#        [0.84060998],
#        [0.79986898],
#        [0.8271091 ],
#        [0.86729412],
#        [0.86308503],
#        [0.85506383],
#        [0.83981576],
#        [0.86745299],
#        [0.91399129],
#        [0.94496402],
#        [0.9408343 ],
#        [0.97966925],
#        [0.95020558],
#        [0.93900774],
#        [0.97847804],
#        [0.92256835],
#        [0.91367367],
#        [0.9026347 ],
#        [0.92836588],
#        [0.94941136],
#        [0.95449405],
#        [0.98665799],
#        [0.97839854],
#        [0.97911339],
#        [0.96974211],
#        [0.96473892],
#        [1.        ],
#        [0.98165467],
#        [0.94369332],
#        [0.92050355],
#        [0.92185362],
#        [0.92201249],
#        [0.94496402],
#        [0.94853777],
#        [0.92201249],
#        [0.92900123],
#        [0.90303181],
#        [0.87467986],
#        [0.86102011],
#        [0.84434259],
#        [0.83806858],
#        [0.82345586],
#        [0.82274114],
#        [0.81900852],
#        [0.90724091],
#        [0.94258148],
#        [0.94123141],
#        [0.95099968],
#        [0.92765103],
#        [0.92360081],
#        [0.91780339],
#        [0.94297859],
#        [0.95449405],
#        [0.92145651],
#        [0.8938194 ],
#        [0.89572545],
#        [0.92677744],
#        [0.92487151],
#        [0.89572545],
#        [0.88317754],
#        [0.85951128],
#        [0.82575903],
#        [0.84696337]])

# %%
#creating the error training data set
#create the scaled error training data set
train_errdata = scaled_errdata[0:training_errdata_len,:]
#split the data into x_errtrain and y_errtrain data sets
x_errtrain = []
y_errtrain = []
for i in range(60, len(train_errdata)):
    x_errtrain.append(train_errdata[i-60:i,0])
    y_errtrain.append(train_errdata[i,0])
    if i<=61:
        print(x_errtrain)
        print(y_errtrain)
        print()
# Out:
# [array([0.19705363, 0.190462  , 0.17606765, 0.14654436, 0.12649154,
#        0.13556496, 0.09758373, 0.09726605, 0.14779519, 0.12895351,
#        0.15559791, 0.13610106, 0.12837772, 0.08299089, 0.12105149,
#        0.1013759 , 0.04737229, 0.1064189 , 0.03542004, 0.05656483,
#        0.04427503, 0.04052257, 0.00966905, 0.        , 0.04469198,
#        0.0419918 , 0.06764351, 0.04639945, 0.0604364 , 0.05940397,
#        0.03283898, 0.04082037, 0.03383169, 0.07564478, 0.06960907,
#        0.08279233, 0.08660432, 0.09704768, 0.12444655, 0.11924474,
#        0.12373183, 0.11600849, 0.10435404, 0.08735879, 0.10270616,
#        0.10058174, 0.11634604, 0.11674315, 0.10762998, 0.12579669,
#        0.13784818, 0.12845715, 0.13657754, 0.14531341, 0.15140868,
#        0.15758333, 0.17027024, 0.17995914, 0.17281159, 0.16534636])]
# [0.16909884709751866]
#
# [array([0.19705363, 0.190462  , 0.17606765, 0.14654436, 0.12649154,
#        0.13556496, 0.09758373, 0.09726605, 0.14779519, 0.12895351,
#        0.15559791, 0.13610106, 0.12837772, 0.08299089, 0.12105149,
#        0.1013759 , 0.04737229, 0.1064189 , 0.03542004, 0.05656483,
#        0.04427503, 0.04052257, 0.00966905, 0.        , 0.04469198,
#        0.0419918 , 0.06764351, 0.04639945, 0.0604364 , 0.05940397,
#        0.03283898, 0.04082037, 0.03383169, 0.07564478, 0.06960907,
#        0.08279233, 0.08660432, 0.09704768, 0.12444655, 0.11924474,
#        0.12373183, 0.11600849, 0.10435404, 0.08735879, 0.10270616,
#        0.10058174, 0.11634604, 0.11674315, 0.10762998, 0.12579669,
#        0.13784818, 0.12845715, 0.13657754, 0.14531341, 0.15140868,
#        0.15758333, 0.17027024, 0.17995914, 0.17281159, 0.16534636]), array([0.190462  , 0.17606765, 0.14654436, 0.12649154, 0.13556496,
#        0.09758373, 0.09726605, 0.14779519, 0.12895351, 0.15559791,
#        0.13610106, 0.12837772, 0.08299089, 0.12105149, 0.1013759 ,
#        0.04737229, 0.1064189 , 0.03542004, 0.05656483, 0.04427503,
#        0.04052257, 0.00966905, 0.        , 0.04469198, 0.0419918 ,
#        0.06764351, 0.04639945, 0.0604364 , 0.05940397, 0.03283898,
#        0.04082037, 0.03383169, 0.07564478, 0.06960907, 0.08279233,
#        0.08660432, 0.09704768, 0.12444655, 0.11924474, 0.12373183,
#        0.11600849, 0.10435404, 0.08735879, 0.10270616, 0.10058174,
#        0.11634604, 0.11674315, 0.10762998, 0.12579669, 0.13784818,
#        0.12845715, 0.13657754, 0.14531341, 0.15140868, 0.15758333,
#        0.17027024, 0.17995914, 0.17281159, 0.16534636, 0.16909885])]
# [0.16909884709751866, 0.1654654816956933]

# %%
#Convert the X_errtrain and Y_errtrain to numpy arrays
x_errtrain , y_errtrain = np.array(x_errtrain), np.array(y_errtrain)

# %%
#Reshape the data
x_errtrain = np.reshape(x_errtrain,(x_errtrain.shape[0],x_errtrain.shape[1],1))
x_errtrain.shape
# Out:
# (348, 60, 1)

# %%
#Building the LSTM error model
errmodel = Sequential()
errmodel.add(LSTM(50, return_sequences=True, input_shape =(x_errtrain.shape[1],1)))
errmodel.add(LSTM(50, return_sequences=True))
errmodel.add(LSTM(50, return_sequences=True))
errmodel.add(LSTM(50, return_sequences=False))
errmodel.add(Dense(25))
errmodel.add(Dense(1))

# %%
#compile the error Model
errmodel.compile(optimizer='adam', loss='mean_squared_error')

# %%
#train the error model
errmodel.fit(x_errtrain, y_errtrain, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 11/11 [==============================] - 9s 70ms/step - loss: 0.0847
# Epoch 2/100
# 11/11 [==============================] - 1s 69ms/step - loss: 0.0154
# Epoch 3/100
# 11/11 [==============================] - 1s 71ms/step - loss: 0.0075
# Epoch 4/100
# 11/11 [==============================] - 1s 122ms/step - loss: 0.0056
# Epoch 5/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0042
# Epoch 6/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0033
# Epoch 7/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0031
# Epoch 8/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0029
# Epoch 9/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0028
# Epoch 10/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0029
# Epoch 11/100
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0028
# Epoch 12/100
# 11/11 [==============================] - 2s 174ms/step - loss: 0.0028
# Epoch 13/100
# 11/11 [==============================] - 2s 178ms/step - loss: 0.0029
# Epoch 14/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0028
# Epoch 15/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0027
# Epoch 16/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0027
# Epoch 17/100
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0027
# Epoch 18/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0027
# Epoch 19/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0026
# Epoch 20/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0028
# Epoch 21/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0029
# Epoch 22/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0029
# Epoch 23/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0029
# Epoch 24/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0025
# Epoch 25/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0025
# Epoch 26/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0026
# Epoch 27/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0024
# Epoch 28/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0025
# Epoch 29/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0024
# Epoch 30/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0028
# Epoch 31/100
# 11/11 [==============================] - 2s 143ms/step - loss: 0.0027
# Epoch 32/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0024
# Epoch 33/100
# 11/11 [==============================] - 2s 144ms/step - loss: 0.0022
# Epoch 34/100
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0024
# Epoch 35/100
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0022
# Epoch 36/100
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0023
# Epoch 37/100
# 11/11 [==============================] - 2s 160ms/step - loss: 0.0025
# Epoch 38/100
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0021
# Epoch 39/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0023
# Epoch 40/100
# 11/11 [==============================] - 1s 128ms/step - loss: 0.0021
# Epoch 41/100
# 11/11 [==============================] - 1s 69ms/step - loss: 0.0020
# Epoch 42/100
# 11/11 [==============================] - 1s 71ms/step - loss: 0.0019
# Epoch 43/100
# 11/11 [==============================] - 1s 76ms/step - loss: 0.0018
# Epoch 44/100
# 11/11 [==============================] - 1s 71ms/step - loss: 0.0018
# Epoch 45/100
# 11/11 [==============================] - 1s 73ms/step - loss: 0.0020
# Epoch 46/100
# 11/11 [==============================] - 1s 70ms/step - loss: 0.0018
# Epoch 47/100
# 11/11 [==============================] - 1s 139ms/step - loss: 0.0019
# Epoch 48/100
# 11/11 [==============================] - 2s 159ms/step - loss: 0.0018
# Epoch 49/100
# 11/11 [==============================] - 2s 161ms/step - loss: 0.0018
# Epoch 50/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0018
# Epoch 51/100
# 11/11 [==============================] - 2s 159ms/step - loss: 0.0017
# Epoch 52/100
# 11/11 [==============================] - 2s 158ms/step - loss: 0.0017
# Epoch 53/100
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0016
# Epoch 54/100
# 11/11 [==============================] - 2s 164ms/step - loss: 0.0016
# Epoch 55/100
# 11/11 [==============================] - 2s 164ms/step - loss: 0.0015
# Epoch 56/100
# 11/11 [==============================] - 2s 160ms/step - loss: 0.0018
# Epoch 57/100
# 11/11 [==============================] - 2s 162ms/step - loss: 0.0017
# Epoch 58/100
# 11/11 [==============================] - 2s 163ms/step - loss: 0.0014
# Epoch 59/100
# 11/11 [==============================] - 2s 157ms/step - loss: 0.0014
# Epoch 60/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0016
# Epoch 61/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0018
# Epoch 62/100
# 11/11 [==============================] - 2s 166ms/step - loss: 0.0017
# Epoch 63/100
# 11/11 [==============================] - 2s 151ms/step - loss: 0.0013
# Epoch 64/100
# 11/11 [==============================] - 2s 153ms/step - loss: 0.0016
# Epoch 65/100
# 11/11 [==============================] - 2s 159ms/step - loss: 0.0016
# Epoch 66/100
# 11/11 [==============================] - 2s 155ms/step - loss: 0.0014
# Epoch 67/100
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0013
# Epoch 68/100
# 11/11 [==============================] - 2s 154ms/step - loss: 0.0014
# Epoch 69/100
# 11/11 [==============================] - 2s 149ms/step - loss: 0.0014
# Epoch 70/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0017
# Epoch 71/100
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0014
# Epoch 72/100
# 11/11 [==============================] - 2s 157ms/step - loss: 0.0014
# Epoch 73/100
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0013
# Epoch 74/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0016
# Epoch 75/100
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0016
# Epoch 76/100
# 11/11 [==============================] - 2s 152ms/step - loss: 0.0015
# Epoch 77/100
# 11/11 [==============================] - 2s 178ms/step - loss: 0.0014
# Epoch 78/100
# 11/11 [==============================] - 2s 158ms/step - loss: 0.0013
# Epoch 79/100
# 11/11 [==============================] - 2s 157ms/step - loss: 0.0012
# Epoch 80/100
# 11/11 [==============================] - 2s 156ms/step - loss: 0.0012
# Epoch 81/100
# 11/11 [==============================] - 2s 166ms/step - loss: 0.0013
# Epoch 82/100
# 11/11 [==============================] - 2s 158ms/step - loss: 0.0015
# Epoch 83/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0019
# Epoch 84/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0020
# Epoch 85/100
# 11/11 [==============================] - 2s 150ms/step - loss: 0.0014
# Epoch 86/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0015
# Epoch 87/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0012
# Epoch 88/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0011
# Epoch 89/100
# 11/11 [==============================] - 2s 146ms/step - loss: 0.0012
# Epoch 90/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0012
# Epoch 91/100
# 11/11 [==============================] - 2s 145ms/step - loss: 0.0012
# Epoch 92/100
# 11/11 [==============================] - 2s 147ms/step - loss: 0.0011
# Epoch 93/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0013
# Epoch 94/100
# 11/11 [==============================] - 2s 148ms/step - loss: 0.0013
# Epoch 95/100
# 11/11 [==============================] - 1s 112ms/step - loss: 0.0012
# Epoch 96/100
# 11/11 [==============================] - 1s 68ms/step - loss: 0.0016
# Epoch 97/100
# 11/11 [==============================] - 1s 70ms/step - loss: 0.0013
# Epoch 98/100
# 11/11 [==============================] - 1s 75ms/step - loss: 0.0011
# Epoch 99/100
# 11/11 [==============================] - 1s 75ms/step - loss: 0.0011
# Epoch 100/100
# 11/11 [==============================] - 1s 74ms/step - loss: 0.0011

# %%
#create the testing error data set
#create a new array containing scaled error values 
test_errdata = scaled_errdata[training_errdata_len - 60: , :]
#create the data sets x_test adn y_test
x_errtest = []
y_errtest = errdataset[training_errdata_len:,:]
for i in range(60, len(test_errdata)):
    x_errtest.append(test_errdata[i-60:i,0])

# %%
#convert the error data to a numpy array
x_errtest = np.array(x_errtest)

# %%
#resahpe the error data
x_errtest = np.reshape(x_errtest,(x_errtest.shape[0],x_errtest.shape[1],1))

# %%
#get the models predicted error values
errpredictions = errmodel.predict(x_errtest)
errpredictions = scaler.inverse_transform(errpredictions)

# %%
rmse2d =  np.sqrt(np.mean(errpredictions - y_errtest)**2)

error2d = []
error2d.append(errpredictions - y_errtest)
nperr2d = np.array(errpredictions - y_errtest)
scaled_error2d = scaler.fit_transform(nperr2d)
plt.figure(figsize=(25,10))
plt.plot(nperr2d, linewidth=3)
#plt.plot(scaled_error, linewidth=3)
plt.title("Scaled 2D Error")
plt.show()

rmse2d
# Out:
# 3.240704555137485

# %%
apple_quote2 = web.DataReader('AAPL', data_source = 'yahoo', start='2022-02-25', end='2022-02-25')
print(apple_quote2['Close'])
# Out:
# Date
# 2022-02-24    162.740005
# 2022-02-25    164.850006
# Name: Close, dtype: float64
